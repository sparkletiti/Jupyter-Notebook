# %%
import pandas as pd

# %%
pwd
# Out:
# '/Users/titioliyide'

# %%
cd Downloads
# Out:
# /Users/titioliyide/Downloads

# %%
df=pd.read_csv ("movies_metadata.csv")
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview     ...        revenue  \
# 0  Led by Woody, Andy's toys live happily in his ...     ...      373554033
# 1  When siblings Judy and Peter discover an encha...     ...      262797249
# 2  A family wedding reignites the ancient feud be...     ...              0
# 3  Cheated on, mistreated and stepped on, the wom...     ...       81452156
# 4  Just when George Banks has recovered from his ...     ...       76578911
#
#   runtime                                   spoken_languages    status  \
# 0      81           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1     104  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2     101           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3     127           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4     106           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0                                                NaN
# 1          Roll the dice and unleash the excitement!
# 2  Still Yelling. Still Fighting. Still Ready for...
# 3  Friends are the people who let you be yourself...
# 4  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count Unnamed: 24
# 0                    Toy Story  FALSE          7.7     5415.0         NaN
# 1                      Jumanji  FALSE          6.9     2413.0         NaN
# 2             Grumpier Old Men  FALSE          6.5       92.0         NaN
# 3            Waiting to Exhale  FALSE          6.1       34.0         NaN
# 4  Father of the Bride Part II  FALSE          5.7      173.0         NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# Write a Pandas program to get the details of the movie with title 'Grumpier Old Men'

# %%
df[df['title']=='Grumpier Old Men']
# Out:
#    adult                              belongs_to_collection  budget  \
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...       0
#
#                                               genres homepage     id  \
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...      NaN  15602
#
#      imdb_id original_language    original_title  \
# 2  tt0113228                en  Grumpier Old Men
#
#                                             overview     ...     revenue  \
# 2  A family wedding reignites the ancient feud be...     ...           0
#
#   runtime                          spoken_languages    status  \
# 2     101  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline             title  video  \
# 2  Still Yelling. Still Fighting. Still Ready for...  Grumpier Old Men  FALSE
#
#   vote_average vote_count Unnamed: 24
# 2          6.5       92.0         NaN
#
# [1 rows x 25 columns]

# %% [markdown]
# Write a Pandas program to sort the DataFrame based on release_date. Let the framework only display the following columns: 'title', 'release_date', 'budget', 'revenue', 'runtime'

# %%
SortbyReleaseDate= df.sort_values(by='release_date')[['title', 'release_date', 'budget', 'revenue', 'runtime']]
SortbyReleaseDate
# Out:
#                                                 title  \
# 4                         Father of the Bride Part II
# 48                              When Night Is Falling
# 28                          The City of Lost Children
# 44                                         To Die For
# 47                                         Pocahontas
# 33                                               Babe
# 49                                 The Usual Suspects
# 38                                           Clueless
# 30                                    Dangerous Minds
# 43                                      Mortal Kombat
# 46                                              Se7en
# 27                                         Persuasion
# 45                      How To Make An American Quilt
# 41                                    Dead Presidents
# 22                                          Assassins
# 36                             Across the Sea of Time
# 26                                       Now and Then
# 20                                         Get Shorty
# 23                                             Powder
# 21                                            Copycat
# 24                                  Leaving Las Vegas
# 0                                           Toy Story
# 34                                         Carrington
# 18                     Ace Ventura: When Nature Calls
# 9                                           GoldenEye
# 37                                       It Takes Two
# 10                             The American President
# 19                                        Money Train
# 15                                             Casino
# 17                                         Four Rooms
# 16                              Sense and Sensibility
# 39                           Cry, the Beloved Country
# 1                                             Jumanji
# 25                                            Othello
# 5                                                Heat
# 6                                             Sabrina
# 11                        Dracula: Dead and Loving It
# 2                                    Grumpier Old Men
# 13                                              Nixon
# 14                                   Cutthroat Island
# 8                                        Sudden Death
# 12                                              Balto
# 3                                   Waiting to Exhale
# 7                                        Tom and Huck
# 35                                   Dead Man Walking
# 40                                        Richard III
# 31                                     Twelve Monkeys
# 42                                        Restoration
# 32                                   Wings of Courage
# 29  In 1930's Shanghai violence was not the proble...
#
#                                          release_date    budget     revenue  \
# 4                                          1995-02-10         0    76578911
# 48                                         1995-05-05         0           0
# 28                                         1995-05-16  18000000     1738611
# 44                                         1995-05-20  20000000    21284514
# 47                                         1995-06-14  55000000   346079773
# 33                                         1995-07-18  30000000   254134910
# 49                                         1995-07-19   6000000    23341568
# 38                                         1995-07-19  12000000           0
# 30                                         1995-08-11         0   180000000
# 43                                         1995-08-18  18000000   122195920
# 46                                         1995-09-22  33000000   327311859
# 27                                         1995-09-27         0           0
# 45                                         1995-10-06  10000000    23574130
# 41                                         1995-10-06  10000000           0
# 22                                         1995-10-06  50000000    30303072
# 36                                         1995-10-20         0           0
# 26                                         1995-10-20  12000000    27400000
# 20                                         1995-10-20  30250000   115101622
# 23                                         1995-10-27         0           0
# 21                                         1995-10-27         0           0
# 24                                         1995-10-27   3600000    49800000
# 0                                          1995-10-30  30000000   373554033
# 34                                         1995-11-08         0           0
# 18                                         1995-11-10  30000000   212385533
# 9                                          1995-11-16  58000000   352194034
# 37                                         1995-11-17         0           0
# 10                                         1995-11-17  62000000   107879496
# 19                                         1995-11-21  60000000    35431113
# 15                                         1995-11-22  52000000   116112375
# 17                                         1995-12-09   4000000     4300000
# 16                                         1995-12-13  16500000   135000000
# 39                                         1995-12-15         0      676525
# 1                                          1995-12-15  65000000   262797249
# 25                                         1995-12-15         0           0
# 5                                          1995-12-15  60000000   187436818
# 6                                          1995-12-15  58000000           0
# 11                                         1995-12-22         0           0
# 2                                          1995-12-22         0           0
# 13                                         1995-12-22  44000000    13681765
# 14                                         1995-12-22  98000000    10017322
# 8                                          1995-12-22  35000000    64350171
# 12                                         1995-12-22         0    11348324
# 3                                          1995-12-22  16000000    81452156
# 7                                          1995-12-22         0           0
# 35                                         1995-12-29  11000000    39363635
# 40                                         1995-12-29         0           0
# 31                                         1995-12-29  29500000   168840000
# 42                                         1995-12-29  19000000           0
# 32                                         1996-09-18         0           0
# 29  [{'iso_3166_1': 'CN', 'name': 'China'}, {'iso_...         0  1995-04-30
#
#     runtime
# 4       106
# 48       96
# 28      108
# 44      106
# 47       81
# 33       89
# 49      106
# 38       97
# 30       99
# 43      101
# 46      127
# 27      104
# 45      116
# 41      119
# 22      132
# 36       51
# 26      100
# 20      105
# 23      111
# 21      124
# 24      112
# 0        81
# 34      121
# 18       90
# 9       130
# 37      101
# 10      106
# 19      103
# 15      178
# 17       98
# 16      136
# 39      106
# 1       104
# 25      123
# 5       170
# 6       127
# 11       88
# 2       101
# 13      192
# 14      119
# 8       106
# 12       78
# 3       127
# 7        97
# 35      122
# 40      104
# 31      129
# 42      117
# 32       50
# 29        0

# %% [markdown]
# Write a Pandas program to get those movies whose revenue more than 2 million and spent less than 1 million. Let the framework only display the following columns: 'title', 'release_date', 'budget', 'revenue', 'runtime'
#
# The revenue and budget columns need to be changed to numeric values and the error in the revenue column needs to be removed.

# %%
df['revenue'] = pd.to_numeric(df['revenue'], errors='coerce')
df['budget'] = pd.to_numeric(df['budget'])
df[((df['revenue']>2000000) & (df['budget']<=1000000))][['title', 'release_date', 'budget', 'revenue', 'runtime']]
# Out:
#                           title release_date  budget      revenue  runtime
# 4   Father of the Bride Part II   1995-02-10       0   76578911.0      106
# 12                        Balto   1995-12-22       0   11348324.0       78
# 30              Dangerous Minds   1995-08-11       0  180000000.0       99
